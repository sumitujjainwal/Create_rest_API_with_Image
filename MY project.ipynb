# %%
import numpy as np
from glob import glob
import cv2
from PIL import Image as img

# %%
my_image = glob('shishaldin.jpg')
my_image = cv2.imread(my_image[0])

# %%
show_image = img.fromarray(my_image)
show_image
# Out:
# <PIL.Image.Image image mode=RGB size=860x580 at 0x1A463436D60>

# %%
print(my_image[0])
print(my_image.size)
# Out:
# [[131 105  88]
#  [132 106  89]
#  [133 107  90]
#  ...
#  [116  90  73]
#  [116  90  73]
#  [116  90  73]]
# 1496400

# %%
print(my_image.shape[1])
# Out:
# 860
